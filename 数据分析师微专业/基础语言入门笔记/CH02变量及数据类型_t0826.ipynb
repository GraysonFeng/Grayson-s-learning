# %%
x1=10
x2=10.0
print(type(x1),type(x2))
# Out:
# <class 'int'> <class 'float'>

# %%
x3='hello world'
x4='hello'
x5="""a
b
c"""
print(x3)
print(x4)
print(x5)
# Out:
# hello world
# hello
# a
# b
# c

# %%
print(type(x3))
# Out:
# <class 'str'>

# %%
# bool 布尔型用于做判断

# %%
a = True
b= False
a==1
# Out:
# True

# %%
b==0
# Out:
# True

# %%
2>3
# Out:
# False

# %%
print(3<5)
# Out:
# True

# %%
# 列表list
lst=[1,2,3,4,5]
print(lst,type(lst))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>

# %%
lst2=[1,2.5,'hello',[1,2,3]]
print(lst2[3],type(lst2[3]))
# Out:
# [1, 2, 3] <class 'list'>

# %%
# 元祖 不可二次赋值 turple

# %%
tup=(1,2,3,4,5)
tup[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-63508e20951f> in <module>()
#       1 tup=(1,2,3,4,5)
# ----> 2 tup[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 字典 dict
dic={'a':100,'b':'hello'}
print(dic,type(dic))
# Out:
# {'a': 100, 'b': 'hello'} <class 'dict'>

# %%
var1=10
print(type(var1))
# Out:
# <class 'int'>

# %%
var2=float(var1)
print(var2,type(var2))
var3=str(var1)
print(var3,type(var3))
# Out:
# 10.0 <class 'float'>
# 10 <class 'str'>

# %%
print(var3+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a95ed6423500> in <module>()
# ----> 1 print(var3+1)
#
# TypeError: must be str, not int

# %%
var1=10.8
var2=int(var1)

# %%
var2
# Out:
# 10

# %%
# 变量

# %%
1a=10
# Out:
#   File "<ipython-input-25-442bddfef1a1>", line 1
#     1a=10
#      ^
# SyntaxError: invalid syntax

# %%
_a=10

# %%
del print#变量名不能和常用语句重合

# %%
print(10)
# Out:
# 10

# %%
#变量名不能有空格
val_2=10
val_2
# Out:
# 10

# %%
a=1
b=10.0
name='jack'
print(a,b,name)
# Out:
# 1 10.0 jack

# %%
#多变量的赋值

a=b=c=1
d,e,f=1,2,'hello'
print(a,b,c,d,e,f)
# Out:
# 1 1 1 1 2 hello

# %%
# 动态变量
var1=10
print(var1)
var1=20
print(var1)
# Out:
# 10
# 20

# %%
# 变量的命名规则
# 1.不能数字开头
# 2.不能和常用功能性名字重合
# 3.不要有空格

# %%
# 算数运算符

# %%
c=a%b#取模

# %%
print(c)
# Out:
# 0

# %%
a,b=30,7
print(a%b)
# Out:
# 2

# %%
print(a//b)#整除
# Out:
# 4

# %%
#取幂
print(a**b)
# Out:
# 21870000000

# %%
#比较运算符
print(2==9)
# Out:
# False

# %%
print(2!=9)
# Out:
# True

# %%
print(2>=9)
# Out:
# False

# %%
# 逻辑运算符
print(True and False)# and 且
# Out:
# False

# %%
print(True or False)# or 或
# Out:
# True

# %%
print(not True)# not 非
# Out:
# False

# %%
print(not 2==9)
# Out:
# True

# %%
print(True==1)
# Out:
# True

# %%
print(2>1 and 2<1)
# Out:
# False

# %%
a,b,c=10.0,0,[1,2,3,4]
print(bool(a),bool(b),bool(c))
# Out:
# True False True

# %%
# 成员运算符
# in/not in
st='abcdef'
lst=[1,2,3,4,5]
dic={'a':1,'b':2,'c':3}
print(1 in lst)
print('d'not in dic)
# Out:
# True
# True

# %%
print('h'in st)
# Out:
# False

# %%
# 注释

# %%
"""
注释只在脚本有作用
在交互式中没有作用"""
# Out:
# '\n注释只在脚本有作用\n在交互式中没有作用'

# %%
# 注释也可以用于标记暂不运行语句

# %%
m=[]
for i in range(10):
  m.append('h'*i)
  print(m)
print(m)
# Out:
# ['']
# ['', 'h']
# ['', 'h', 'hh']
# ['', 'h', 'hh', 'hhh']
# ['', 'h', 'hh', 'hhh', 'hhhh']
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh']
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh', 'hhhhhh']
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh', 'hhhhhh', 'hhhhhhh']
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh', 'hhhhhh', 'hhhhhhh', 'hhhhhhhh']
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh', 'hhhhhh', 'hhhhhhh', 'hhhhhhhh', 'hhhhhhhhh']
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh', 'hhhhhh', 'hhhhhhh', 'hhhhhhhh', 'hhhhhhhhh']

# %%
m=[]
for i in range(10):
  m.append('h'*i)
  #print(m)
print(m)
# Out:
# ['', 'h', 'hh', 'hhh', 'hhhh', 'hhhhh', 'hhhhhh', 'hhhhhhh', 'hhhhhhhh', 'hhhhhhhhh']

# %%
m=[]
"""for i in range(10):
  m.append('h'*i)
  #print(m)"""
print(m)
# Out:
# []
